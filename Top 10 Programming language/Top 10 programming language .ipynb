# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\dhruv\Desktop\Most Popular Programming Languages from 2004 to 2020.csv')

# %%
df.head()
# Out:
#              Date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi   Go  Groovy  \
# 0       July 2004  0.36  0.38   9.97  4.86   0.44   0.0    2.89  0.0    0.03
# 1     August 2004  0.37  0.38   9.65  5.20   0.48   0.0    2.78  0.0    0.07
# 2  September 2004  0.43  0.43   9.46  5.29   0.53   0.0    2.77  0.0    0.08
# 3    October 2004  0.42  0.39   9.16  5.43   0.55   0.0    2.84  0.0    0.09
# 4   November 2004  0.39  0.39   9.37  5.40   0.57   0.0    2.85  0.0    0.08
#
#    ...    PHP  Python     R  Ruby  Rust  Scala  Swift  TypeScript   VBA  \
# 0  ...  18.77    2.60  0.40  0.35  0.08   0.03    0.0         0.0  1.49
# 1  ...  18.88    2.75  0.42  0.41  0.10   0.03    0.0         0.0  1.52
# 2  ...  18.93    2.84  0.42  0.43  0.11   0.03    0.0         0.0  1.62
# 3  ...  18.92    2.99  0.43  0.47  0.12   0.04    0.0         0.0  1.65
# 4  ...  19.02    2.93  0.43  0.46  0.14   0.04    0.0         0.0  1.55
#
#    Visual Basic
# 0          8.84
# 1          8.96
# 2          8.82
# 3          8.70
# 4          8.50
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (194, 29)

# %%
df.isnull().sum()
# Out:
# Date            0
# Abap            0
# Ada             0
# C/C++           0
# C#              0
# Cobol           0
# Dart            0
# Delphi          0
# Go              0
# Groovy          0
# Haskell         0
# Julia           0
# Kotlin          0
# Java            0
# Javascript      0
# Lua             0
# Matlab          0
# Objective-C     0
# Perl            0
# PHP             0
# Python          0
# R               0
# Ruby            0
# Rust            0
# Scala           0
# Swift           0
# TypeScript      0
# VBA             0
# Visual Basic    0
# dtype: int64

# %%
#Converting Date column into proper Date-Time format

df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#             Abap   Ada  C/C++    C#  Cobol  Dart  Delphi   Go  Groovy  \
# Date
# 2004-07-01  0.36  0.38   9.97  4.86   0.44   0.0    2.89  0.0    0.03
# 2004-08-01  0.37  0.38   9.65  5.20   0.48   0.0    2.78  0.0    0.07
# 2004-09-01  0.43  0.43   9.46  5.29   0.53   0.0    2.77  0.0    0.08
# 2004-10-01  0.42  0.39   9.16  5.43   0.55   0.0    2.84  0.0    0.09
# 2004-11-01  0.39  0.39   9.37  5.40   0.57   0.0    2.85  0.0    0.08
#
#             Haskell  ...    PHP  Python     R  Ruby  Rust  Scala  Swift  \
# Date                 ...
# 2004-07-01     0.23  ...  18.77    2.60  0.40  0.35  0.08   0.03    0.0
# 2004-08-01     0.21  ...  18.88    2.75  0.42  0.41  0.10   0.03    0.0
# 2004-09-01     0.22  ...  18.93    2.84  0.42  0.43  0.11   0.03    0.0
# 2004-10-01     0.21  ...  18.92    2.99  0.43  0.47  0.12   0.04    0.0
# 2004-11-01     0.25  ...  19.02    2.93  0.43  0.46  0.14   0.04    0.0
#
#             TypeScript   VBA  Visual Basic
# Date
# 2004-07-01         0.0  1.49          8.84
# 2004-08-01         0.0  1.52          8.96
# 2004-09-01         0.0  1.62          8.82
# 2004-10-01         0.0  1.65          8.70
# 2004-11-01         0.0  1.55          8.50
#
# [5 rows x 28 columns]

# %%
columns = df.columns.tolist()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.figure(figsize = (20,10))

# making a heatmap for analysing the distribution using the mako colourmap

hmap_one = sns.heatmap(df, cmap="mako", yticklabels = False)

# %%
# Filtering out the top 10 languages
df = df.loc[:, (df.mean() > 2.5)]
plt.figure(figsize = (20,10))

# making a heatmap using the mako colourmap
hmap_two = sns.heatmap(df, cmap="mako", yticklabels = False)

# %%
plt.figure(figsize = (30,10))
# Plotting a line for each language on the plot
for lang in columns:
    ax = sns.lineplot(x = df.index, y = df[lang], label = lang, linewidth = 4)

# setting background colour to white
ax.set_facecolor("white")
# Plotting basic axes and title
plt.title("Line Chart")
plt.ylabel("Popularity in %")
plt.xlabel("Time in date-time format")
#. Customizing the legends 
legend = plt.legend(loc = 9, ncol = 10, fancybox = True, facecolor = 'black', edgecolor = 'blue', fontsize = 14)
plt.setp(legend.get_texts(), color='w')
plt.yticks()
plt.show()

# %%
sns.barplot( yticklabels=False, hue="genre", data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-ee9071f3e78b> in <module>
# ----> 1 sns.barplot( yticklabels=False, hue="genre", data=df)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1613         """Initialize the plotter."""
#    1614         self.establish_variables(x, y, hue, data, orient,
# -> 1615                                  order, hue_order, units)
#    1616         self.establish_colors(color, palette, saturation)
#    1617         self.estimate_statistic(estimator, ci, n_boot, seed)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#      43             if hue is not None:
#      44                 error = "Cannot use `hue` without `x` or `y`"
# ---> 45                 raise ValueError(error)
#      46
#      47             # No hue grouping with wide inputs
#
# ValueError: Cannot use `hue` without `x` or `y`
